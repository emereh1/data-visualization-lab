# %% [markdown]
# # Lab Instructions
#
# You are part of a data team for a financial institution that uses an AI model to determine who will and will not be granted a loan.  Recently, there have been complaints from customers that the model unfairly discriminates based on the applicant's age and sex. A court has ordered that the financial institution must provide information about how the model works.
#
# Data from recent loan applications is given in `loan_data.csv`.  The data dictionary is below:
#
# | Feature              | Description | Data Type |
# | :---------------- | :------: | ----: |
# |person_age|Age of the person|Float
# |person_gender|Gender of the person|Categorical
# |person_education|Highest education level|Categorical
# |person_income|Annual income|Float
# |person_emp_exp|Years of employment experience|Integer
# |person_home_ownership|Home ownership status (e.g., rent, own, mortgage)|Categorical
# |loan_amnt|Loan amount requested|Float
# |loan_intent|Purpose of the loan|Categorical
# |loan_int_rate|Loan interest rate|Float
# |loan_percent_income|Loan amount as a percentage of annual income|Float
# |cb_person_cred_hist_length|Length of credit history in years|Float
# |credit_score|Credit score of the person|Integer
# |previous_loan_defaults_on_file|Indicator of previous loan defaults|Categorical
# |loan_status (target variable)|Loan approval status: 1 = approved; 0 = rejected|Integer
#
# Visualize the relationship between age, sex and 5 other features with `loan_status`.  Which features seem to drive the model's decision to grant a loan?  Which seem unrelated?  Should the financial institution be concerned about potential legal trouble?  Make sure to justify your answers with specific references to your visualizations.

# %%
# Import necessary libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset
data = pd.read_csv('loan_data.csv')

# Explore the first few rows of the data to understand the structure
print(data.head())

# Checking for missing values
print(data.isnull().sum())

# Visualizing the relationship between 'age' and 'loan_status'
plt.figure(figsize=(8,6))
sns.boxplot(x='loan_status', y='person_age', data=data)
plt.title('Age vs Loan Status')
plt.xlabel('Loan Status (0 = Rejected, 1 = Approved)')
plt.ylabel('Age')
plt.show()

# Visualizing the relationship between 'sex' and 'loan_status'
plt.figure(figsize=(8,6))
sns.countplot(x='person_gender', hue='loan_status', data=data)
plt.title('Gender vs Loan Status')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# Visualizing 'income' vs 'loan_status'
plt.figure(figsize=(8,6))
sns.boxplot(x='loan_status', y='person_income', data=data)
plt.title('Income vs Loan Status')
plt.xlabel('Loan Status (0 = Rejected, 1 = Approved)')
plt.ylabel('Annual Income')
plt.show()

# Visualizing 'credit_score' vs 'loan_status'
plt.figure(figsize=(8,6))
sns.boxplot(x='loan_status', y='credit_score', data=data)
plt.title('Credit Score vs Loan Status')
plt.xlabel('Loan Status (0 = Rejected, 1 = Approved)')
plt.ylabel('Credit Score')
plt.show()

# Visualizing 'loan_amnt' vs 'loan_status'
plt.figure(figsize=(8,6))
sns.boxplot(x='loan_status', y='loan_amnt', data=data)
plt.title('Loan Amount vs Loan Status')
plt.xlabel('Loan Status (0 = Rejected, 1 = Approved)')
plt.ylabel('Loan Amount Requested')
plt.show()

# Visualizing the relationship between 'home_ownership' and 'loan_status'
plt.figure(figsize=(8,6))
sns.countplot(x='person_home_ownership', hue='loan_status', data=data)
plt.title('Home Ownership vs Loan Status')
plt.xlabel('Home Ownership Status')
plt.ylabel('Count')
plt.show()

# Visualizing the relationship between 'loan_int_rate' and 'loan_status'
plt.figure(figsize=(8,6))
sns.boxplot(x='loan_status', y='loan_int_rate', data=data)
plt.title('Loan Interest Rate vs Loan Status')
plt.xlabel('Loan Status (0 = Rejected, 1 = Approved)')
plt.ylabel('Loan Interest Rate')
plt.show()

# Visualizing the relationship between 'loan_percent_income' and 'loan_status'
plt.figure(figsize=(8,6))
sns.boxplot(x='loan_status', y='loan_percent_income', data=data)
plt.title('Loan Percent Income vs Loan Status')
plt.xlabel('Loan Status (0 = Rejected, 1 = Approved)')
plt.ylabel('Loan as Percent of Income')
plt.show()

# Visualizing the relationship between 'person_education' and 'loan_status'
plt.figure(figsize=(8,6))
sns.countplot(x='person_education', hue='loan_status', data=data)
plt.title('Education Level vs Loan Status')
plt.xlabel('Education Level')
plt.ylabel('Count')
plt.show()

# Visualizing the relationship between 'previous_loan_defaults_on_file' and 'loan_status'
plt.figure(figsize=(8,6))
sns.countplot(x='previous_loan_defaults_on_file', hue='loan_status', data=data)
plt.title('Previous Loan Defaults vs Loan Status')
plt.xlabel('Previous Loan Defaults')
plt.ylabel('Count')
plt.show()

# Correlation Heatmap to explore relationships between numerical features
numeric_features = ['person_age', 'person_income', 'person_emp_exp', 'loan_amnt', 
                    'loan_int_rate', 'loan_percent_income', 'cb_person_cred_hist_length', 'credit_score']

correlation_matrix = data[numeric_features].corr()
plt.figure(figsize=(10,8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Correlation Heatmap of Numerical Features')
plt.show()

# Identifying which features seem to drive the model's decision to grant a loan
# Features that show clear relationships with loan approval are likely:
# 'credit_score', 'loan_amnt', 'person_income', 'loan_int_rate', and 'loan_percent_income'.
# Age and sex might show weaker relationships with loan status, but this depends on the visual analysis.
# Out:
#    person_age person_gender person_education  person_income  person_emp_exp  \
# 0          71          male        Associate   46817.176426               3
# 1          34          male      High School   79093.494008              17
# 2          80          male        Associate   67819.614431              20
# 3          40        female        Associate   49599.861220               0
# 4          43          male        Doctorate   99833.900180               8
#
#   person_home_ownership     loan_amnt loan_intent  loan_int_rate  \
# 0                  RENT  11567.737650     MEDICAL      10.351469
# 1                   OWN   9519.674498     MEDICAL      11.168902
# 2                   OWN  16226.604002    PERSONAL      12.293112
# 3                  RENT  15641.221708     VENTURE      10.327926
# 4                   OWN  12727.942517   EDUCATION       9.338069
#
#    loan_percent_income  cb_person_cred_hist_length  credit_score  \
# ...

# %% [markdown]
# ## Insights
# - **Credit Score**: Strongly correlated with loan approval.
# - **Loan Amount**: Applicants requesting larger amounts tend to be rejected more.
# - **Gender**: No significant discrimination, but further statistical testing is recommended.

# %% [markdown]
# ## Model Ethics
# The model might show discrimination based on **Age** if older applicants are rejected more frequently. This could pose legal risks, especially if the rejection rate is significantly higher for certain age groups. Similarly, if **Sex** shows a bias, adjustments should be made to ensure the model is fair.

# %% [markdown]
# ## Conclusion
# The model seems to be primarily influenced by financial factors such as Credit Score, Income, and Loan Amount. However, Age and Sex did not show a strong correlation with loan approval. If any discrimination based on these factors is identified, especially with older applicants or a specific gender, it could pose legal risks. The model may need adjustments to ensure fairness and avoid any unintended bias.
